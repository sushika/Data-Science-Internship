# %%
import pandas as pd
#creating a dataframe
data = {
    'cars':['santro' , 'BMW' , 'Audi' , 'Jeep'],
    'duration':[50,49,45,60]
}
print(pd.DataFrame(data))# a dataframe is a table of data
# Out:
#      cars  duration
# 0  santro        50
# 1     BMW        49
# 2    Audi        45
# 3    Jeep        60

# %%
#creating pandas series using series() from a list of values
import pandas as pd
fruits = ['apple','banana','mango']#list of data (fruits)
myd = pd.Series(fruits)#series is like a coloumn in  a Dataframe
print(myd)
# Out:
# 0     apple
# 1    banana
# 2     mango
# dtype: object

# %%
#lABLES in pandas
import pandas as pd
#if no lables are mentioned the first value has 0 as its lable and the successive value has 1 
data = {
    'cars':['santro' , 'BMW' , 'Audi' , 'Jeep'],
    'duration':[50,49,45,60]
}
print(pd.DataFrame(data))
#assigning lables manually using index
print('assigning lables manually to the data')
fruits = ['apple','banana','mango']#list of data (fruits)
myd = pd.Series(fruits,index = ['a','b','c'])
print(myd)
#series can also be created using Dictionaries or key objects
schedule = {'monday':'maths','tuesday':'science','wednesday':'socialstudies','thursday':'english','friday':'PET'}
print(pd.Series(schedule))
# Out:
#      cars  duration
# 0  santro        50
# 1     BMW        49
# 2    Audi        45
# 3    Jeep        60
# assigning lables manually to the data
# a     apple
# b    banana
# c     mango
# dtype: object
# monday               maths
# tuesday            science
# wednesday    socialstudies
# thursday           english
# friday                 PET
# dtype: object

# %%
import pandas as pd
#locating specific rows from the dataset
data = {
    'Days':['mondays','tuesday','wednesday','Thursday','friday'],
    'subjects':['english','science','maths','social','physicaledu'],
    'faculty':['Ram','Ajay','Radha','Anil','Abhay']
}
df = pd.DataFrame(data)
print(df.loc[3])
#outputs the data in 3rd index of the dataframe
print(df.loc[[0,3]])#gives the data from the 0th and 3rd indices
# Out:
# Days        Thursday
# subjects      social
# faculty         Anil
# Name: 3, dtype: object
#        Days subjects faculty
# 0   mondays  english     Ram
# 3  Thursday   social    Anil

# %%
import pandas as pd
df = pd.read_csv('automobile.csv')

# %%
pd.options.display.max_rows #displays the maximum no.of rows allowed to view in the system from the dataset if the no.of rows in the dataset exceeds the limit it only shows the first 5 and last 5 rows
# Out:
# 60

# %%
print(df.to_string()) #displays the whole dataset
# Out:
#      symboling  normalized-losses           make fuel-type aspiration num-of-doors   body-style drive-wheels engine-location  wheel-base  length  width  height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  price
# 0            3                NaN    alfa-romero       gas        std          two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc             four          130        mpfi  3.47    2.68               9.00       111.0    5000.0        21           27  13495
# 1            3                NaN    alfa-romero       gas        std          two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc             four          130        mpfi  3.47    2.68               9.00       111.0    5000.0        21           27  16500
# ...

# %%
print(df.info())
#info() function gives the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
print(df.tail(3))#displays the bottom most rows of the dataset however,tail() bottom 5 rows
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 198         -1               95.0  volvo       gas        std         four
# 199         -1               95.0  volvo    diesel      turbo         four
# 200         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 198         mpfi  3.58    2.87               8.8      134.0    5500.0
# 199          idi  3.01    3.40              23.0      106.0    4800.0
# 200         mpfi  3.78    3.15               9.5      114.0    5400.0
#
#     city-mpg  highway-mpg  price
# 198       18           23  21485
# ...

# %%
print(df.head())
#diaplays top5 rows of the dataset
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#removing the empty cells from the dataset
df.dropna()
#removes the emptycells from the dataset and displays a new dataframe with no empty cells however if inplace is set to True the actual dataset is manipulated
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2              164.0   audi       gas        std         four
# 4            2              164.0   audi       gas        std         four
# 6            1              158.0   audi       gas        std         four
# 8            1              158.0   audi       gas      turbo         four
# 9            2              192.0    bmw       gas        std          two
# ..         ...                ...    ...       ...        ...          ...
# 196         -1               95.0  volvo       gas        std         four
# 197         -1               95.0  volvo       gas      turbo         four
# 198         -1               95.0  volvo       gas        std         four
# 199         -1               95.0  volvo    diesel      turbo         four
# 200         -1               95.0  volvo       gas      turbo         four
#
# ...

# %%
x=df['city-mpg'].mean()
print(df['city-mpg'].fillna(x))#emptycells are replaced with the mean of the attribute values
#similarly they can be replaced with the median values too
y = df['normalized-losses'].median()
print(df['normalized-losses'].fillna(y))
#replacing with mode i.e most frequently occuring values
z= df['bore'].mode()
print(df['bore'].fillna(z))
# Out:
# 0      21
# 1      21
# 2      19
# 3      24
# 4      18
#        ..
# 196    23
# 197    19
# 198    18
# 199    26
# 200    19
# Name: city-mpg, Length: 201, dtype: int64
# 0      115.0
# 1      115.0
# 2      115.0
# 3      164.0
# 4      164.0
#        ...
# 196     95.0
# 197     95.0
# 198     95.0
# 199     95.0
# 200     95.0
# Name: normalized-losses, Length: 201, dtype: float64
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 196    3.78
# 197    3.78
# 198    3.58
# 199    3.01
# 200    3.78
# Name: bore, Length: 201, dtype: float64

# %%
#finding duplicates if any in the dataset
import pandas as pd
df = pd.read_csv('data.csv')
print(df.duplicated().head(50))
x = df.drop_duplicates()#removes the duplicated rows from the dataset
print(x.head(40))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# ...

# %%
import pandas as pd
df = pd.read_csv('data.csv')
print(df.corr())
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000
